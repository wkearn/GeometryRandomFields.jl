# %% [markdown]
# If you're following along, you'll need to checkout the `dev` branch of `Plots.jl`. **Don't do this if you're running on JuliaBox**, you apparently have to run package management commands through the console.

# %%
Pkg.checkout("Plots","dev")
# Out:
# INFO: Checking out Plots dev...
# INFO: Pulling Plots latest dev...
# WARNING: unknown Lazy commit 8709dc31, metadata may be ahead of package cache
# INFO: No packages to install, update or remove

# %%
using Plots

# %%
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# # Julia
#
# - Created in 2012 at MIT by Viral Shah, Stefan Karpinski and Jeff Bezanson among others
# - Aims for high-performance in a dynamic language
# - Takes advantage of a Just-In-Time compiler based on [LLVM](http://llvm.org)

# %% [markdown]
# # Why should you use Julia?
#
# - <s>You don't have any need to plot anything ever</s> `Plots.jl` is awesome!
# - You want your code to break randomly
# - You currently use MATLAB
#
# **Do not use Julia just because you want code to go faster.**
#
# Some things will be fast right off the bat, but a lot of that has to do more with solid integration with libraries (linear algebra and FFTs, for instance) than with the compiler innovations.
#
# The developers have spent a lot of time making Julia code go quickly, but well-optimized Julia code, as we'll see in the example below, takes some effort to write.

# %% [markdown]
# # Example: The Geometry of Random Fields
#
# Random fields show up in a lot of different scientific applications (kriging in geostatistics, for instance), and one might be interested in certain geometric properties of what is known as an excursion set, the set of points for which the field takes values above a certain threshold. Let's see how to simulate some random fields and calculate these geometric properties in Julia.

# %% [markdown]
# ## Covariance functions
#
# Gaussian random fields (in which the finite-dimensional distributions are Gaussian) are essentially defined by a covariance function, which describes how the value of the field at two points in space is related. Isotropic and stationary random fields have a covariance function which varies only as a function of distance between the two points, and we'll restrict ourselves to such fields where the covariance function takes the form of a Gaussian.

# %%
abstract AbstractCovarianceFunction

# %%
abstract StationaryCovarianceFunction <: AbstractCovarianceFunction

# %%
Base.call(f::StationaryCovarianceFunction,x,y) = f(sqrt(sumabs2(x-y)))
# Out:
# call (generic function with 1972 methods)

# %%
doc"""
A Gaussian covariance function is of the form

C(x_1,x_2) = σ^2 e^{-\|x_1-x_2\|^2/2L^2}

where L is the bandwidth of the Gaussian kernel.
"""
type GaussianCovarianceFunction <: StationaryCovarianceFunction
    L::Real
    σ::Real
end

Base.call(f::GaussianCovarianceFunction,h) = f.σ^2*exp(-h^2/(2*f.L^2))
# Out:
# call (generic function with 1975 methods)

# %%
?GaussianCovarianceFunction
# Out:
# search:
# A Gaussian covariance function is of the form
#
# C(x_1,x_2) = σ^2 e^{-\|x_1-x_2\|^2/2L^2}
#
# where L is the bandwidth of the Gaussian kernel.
# GaussianCovarianceFunction

# %%
gf = GaussianCovarianceFunction(16,1)
plot(x->gf(x),0,64,xlabel="Lag",ylabel="Covariance",legend=false)
# Out:
# [Plots.jl] Initializing backend: gr
# INFO: Recompiling stale cache file /home/wkearn/.julia/lib/v0.4/GR.ji for module GR.
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <defs>
#   <clipPath id="clip02">
#     <rect x="75" y="20" width="496" height="331"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,336.8 570,336.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,323.6 570,323.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,310.4 570,310.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,297.2 570,297.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,284 570,284
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,270.8 570,270.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,257.6 570,257.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,244.4 570,244.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,231.2 570,231.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,218 570,218
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,204.8 570,204.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,191.6 570,191.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,178.4 570,178.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,165.2 570,165.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,152 570,152
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,138.8 570,138.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,125.6 570,125.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,112.4 570,112.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,99.2 570,99.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,86 570,86
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,72.8 570,72.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,59.6 570,59.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,46.4 570,46.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,33.2 570,33.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,20 570,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   103.286,350 103.286,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   131.571,350 131.571,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   159.857,350 159.857,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   188.143,350 188.143,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   216.429,350 216.429,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   244.714,350 244.714,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   273,350 273,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   301.286,350 301.286,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   329.571,350 329.571,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   357.857,350 357.857,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   386.143,350 386.143,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   414.429,350 414.429,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   442.714,350 442.714,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   471,350 471,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   499.286,350 499.286,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   527.571,350 527.571,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   555.857,350 555.857,20
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 62.3709, 354.23)" x="62.3709" y="354.23">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 50.12, 288.23)" x="50.12" y="288.23">0.2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 50.12, 222.23)" x="50.12" y="222.23">0.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 50.12, 156.23)" x="50.12" y="156.23">0.6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 50.12, 90.2299)" x="50.12" y="90.2299">0.8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 50.12, 24.2299)" x="50.12" y="24.2299">1.0</text>
# </g>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,350 75,350 83.9237,350 75,350 75,336.8 79.4619,336.8 75,336.8 75,323.6 79.4619,323.6 75,323.6
#   75,310.4 79.4619,310.4 75,310.4 75,297.2 79.4619,297.2 75,297.2 75,284 83.9237,284 75,284 75,270.8
#   79.4619

# %% [markdown]
# ## Field generators
#
# To generate a random field, we use a technique called circulant embedding which uses fast Fourier transforms rather than constructing the entire covariance matrix.

# %%
randc(m,n) = randn(m,n)+im*randn(m,n)

function grf(m,n,C::StationaryCovarianceFunction)
    tx = collect(0:m-1)
    ty = collect(0:n-1)
    Rjs = zeros(m,n)
    for j in 1:n, i in 1:m
        Rjs[i,j] = C([tx[1],ty[1]],[tx[i],ty[j]])
    end
    Sjs = [Rjs Rjs[:,end] Rjs[:,end:-1:2]]
    Sjs2 = [Sjs ; Sjs[end,:] ; Sjs[end:-1:2,1] Sjs[end:-1:2,end:-1:2]]
    Γ = fft(Sjs2)
    Z = randc(size(Sjs2)...)    
    fft(sqrt(Γ./(4*m*n)).*Z)[1:m,1:n]
end
# Out:
# grf (generic function with 1 method)

# %%
grf(128,128,gf) # Run once for good luck!
@time M = grf(1024,1024,gf);
# Out:
#   1.808300 seconds (11.53 M allocations: 1.047 GB, 10.54% gc time)

# %%
Z1,Z2 = reim(M)
heatmap(Z1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
#
#   "/>
# <g clip-path="url(#clip02)">
# <image width="435" height="329" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAbMAAAFJCAYAAAAR5MP4AAAgAElEQVR4nLS925Lruo4tOMSLb7lq
# d52HPue1//+D+qGjI/oT9m2l05mi5H4gAQIgKDtX1UHEDHs6bYmiROI2MLD8f//v//P8v//1fyGH
# HSnu9TVsSGEDSdkjv36tCese8PUTcf8OWAvavyfWUr+/rk/+7Vrq+5yW+poX5FT/nxNwOz+R0xM5
# PnHNBSnusFK2UI+1B/5MjveSfnAJ30hLQUJBwqp/j9xeExLqIBNWnMsdcftB3FeEbUXYfhCK/u2e
# MvZ4wppv+M4f2EJGQUZB4u/QMc/7HWlf1TEBYI/1/D/5AyVkfIcbHs8LyjOiPBMe5cTXRtcKgOci
# h/oq74knKWxIS6lzgYLzfsd5/URe7wjbD9L3p762eMLP7T/xkz/wnW748/kfeOxnPMqJ77M33/R8
# XMK3Ow66rrJHlD1i3YO6h/Iah2ugc8Qd17Sq86SliHOkYf6+1jTMXw47rrnwM3JZHsPzAYDvaXkm
# vgZ5Ln5vrulrrX9bt/Z8x2cdey7q2bwsD/V8WNniCSVk9Xw99nMfTzuvmiuxTuXcDNcmxq9+336T
# lk2tnbivapxxr/NFa4TEWytAfa72WK9FXtuRpL0fi74r50Le77JHfJXM9/prTVi3BWup94DuBVDv
# B+0v8tmi5xjo68bOg7z2o/mgeQjOfQWAcv5AOX3gfv5PXvt/lhu+SsbXmvD1U+/rWhbk9ORx035I
# z1FaCv4In7x3ndZP3mNI1nzD/fyfeOCKP7cP/P3rhn89Mu7fAfeH3qdzAm6Xhffg62nj9SLnZrge
# oQ9oHdBe8fUTsZal3Q/wuaTU/b9e4+1c78ffzj91rcfvw/tAkvZxDSf7JTngV5unFKnISIHV/5Ny
# aptZeVZFlusFAQvytuB23gEkpH3nzRvQCoweXqnw+oOoFyPJFjISVhRkVjqeeA/lHk/D9+ziAoC0
# pHr+gwW7vVjMVmaKzDMy6

# %% [markdown]
# And I said we were interested in the excursion set of a Gaussian random field, so let's see what that looks like:

# %%
heatmap(Z1.>1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <defs>
#   <clipPath id="clip02">
#     <rect x="75" y="20" width="436" height="331"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,320 510,320
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,290 510,290
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,260 510,260
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,230 510,230
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,200 510,200
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,170 510,170
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,140 510,140
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,110 510,110
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,80 510,80
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,50 510,50
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,20 510,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   114.545,350 114.545,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   154.091,350 154.091,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   193.636,350 193.636,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   233.182,350 233.182,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   272.727,350 272.727,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   312.273,350 312.273,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   351.818,350 351.818,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   391.364,350 391.364,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   430.909,350 430.909,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   470.455,350 470.455,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   510,350 510,20
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; font-family:Arial; font-size:14; text-anchor:start;" transform="rotate(0, 55.219, 353.882)" x="55.219" y="353.882">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; font-family:Arial; font-size:14; text-anchor:start;" transform="rotate(0, 40.2274, 203.882)" x="40.2274" y="203.882">500</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000
# tQlPihA459zxvJN5EYVM5+r54bXK3FGfcbrs3eP14G7uboXfKIwmOW5p2J/uX0TGIvd7Ntute7we
# kte1RXK/tStjtrabOl327ubutnjHtSaMmhRBDTbbLdsmoTZeWdVUlinycTzv3OP14B6vh+pjrEGO
# W59QPZxGbWkjHCP1hGKZEoO94X2VdlCM1PG8c0/3L9kG7fnh1bnIAvOCv/YMDYt0DuXbnFv+Li3K
# Rzs58ne67Ica36f7F5IsWiN1/kYyYs6Vu3a7OplRyd1ppQjj0jNq7XqpO0rvZlv7Nn/sj518rZ7S
# apMjA5svnwXeRB+5pxdpWpxWNRoy743hXuscd5TdnMxSSd0hU08u82e0JvoOkW9K2R3WPEFM584r
# wJ5PLt/+/a/1K1RB8xyWeHVS0RaI4xwtuK4lXRizlEixqfJOEU4tE1ab1N3h6bKvHhk5fUdNi4uT
# Hr9pTs6G0RKb7ZY0jxoN2RKny55l0576G6ExGtLNOEXD6ak3fPCCFDF3Z4ugCUm0ut64sWCwS/QF
# xVXMsW5GkBd/jTKdj1+gzGHQpJAwKNTf7MGoUe4zJWhxMhhBAR/Pu1V55Bp3KXkJ6UkNutMbtaCb
# cT6of/7xl/v2738mdk651PSHj4KEvOS4PTkX3FQZlXxfTN5aRfS1WgOWdAslYnmJ0L0yZ9SitHHR
# YLyW+GDMQhM0TajVdifBu

# %% [markdown]
# ## Euler characteristic calculation
#
# The geometrical properties of excursion sets of random fields are captured by something called the Euler characteristic, $\Gamma$. This essentially measures the number of connected components of the excursion set minus the number of holes in those components. It is useful because we can write down an expectation for it
#
# $$\operatorname{E}[\Gamma(A_u)] = \left(\frac{|A|}{(2\pi)^{3/2}}u
# +\frac{2|\partial A|}{2\pi}\right)e^{-u^2/2} + \Psi(u)$$

# %%
EΓ(x,J) = J^2/(2pi)^(3/2)*x.*exp(-x.^2/2) + 
2J/(2pi)*exp(-x.^2/2) +
1/sqrt(2pi)*(1-0.5*(1+erf(x/sqrt(2))))
# Out:
# EΓ (generic function with 1 method)

# %% [markdown]
# And to calculate it, we approximate the excursion set by a lattice of pixels in the image. If two adjacent pixels are both in the excursion set, we connect them with an edge. The approximate Euler characteristic is the number of faces on the resulting graph, minus the number of edges, plus the number of vertices.

# %%
function Γ(Z::AbstractMatrix{Float64},u)
    m,n = size(Z)
    F,E,P = 0,0,0
    for j in 1:n-1
        for i in 1:m-1
            if Z[i,j]>u
                P += 1
                ns1 = Z[i+1,j]>u
                ns2 = Z[i+1,j+1]>u
                ns3 = Z[i,j+1]>u
                E += ns1+ns2+ns3
                F += (ns1&ns2)+(ns2&ns3)
            end
        end
        if Z[m,j]>u
            P += 1
            E += Z[m,j+1]>u
        end
    end
    for i in 1:m-1
        if Z[i,n]>u
            P += 1
            E += Z[i+1,n]>u
        end
    end
    P += Z[m,n]>u
    F-E+P
end

function Γ(Z::AbstractMatrix{Float64},u::AbstractVector)
    γs = zeros(Int,length(u))
    for i in 1:length(u)
        γs[i] = Γ(Z,u[i])
    end
    γs
end
# Out:
# Γ (generic function with 2 methods)

# %%
plot(x->EΓ(x,64),0,5,legend=false,xlabel="Threshold",ylabel="Gamma")
plot!(x->Γ(Z1,x),0,5)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
#
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   570,350 570,350 561.076,350 570,350 570,331.667 565.538,331.667 570,331.667 570,313.333 565.538,313.333 570,313.333
#   570,295 565.538,295 570,295 570,276.667 565.538,276.667 570,276.667 570,258.333 561.076,258.333 570,258.333 570,240
#   565.538,240 570,240 570,221.667 565.538,221.667 570,221.667 570,203.333 565.538,203.333 570,203.333 570,185 565.538,185
#   570,185

# %% [markdown]
# The expected Euler characteristic is, after all, a statistic, so let's generate a whole bunch of random fields, calculate the mean Euler characteristic and see how well it matches. And see how quick we can do it.

# %%
Zs = Matrix{Float64}[]
@time for i in 1:64
    M = grf(512,512,gf)
    push!(Zs,real(M))
    push!(Zs,imag(M))
end
# Out:
#  27.623069 seconds (167.79 M allocations: 16.751 GB, 20.64% gc time)

# %%
@time γs = Int[Γ(Z,u) for Z in Zs, u in -5:0.1:5];
# Out:
#   8.500860 seconds (64.95 k allocations: 1.717 MB)

# %%
γm = vec(mean(γs,1))
γv = vec(std(γs,1));

# %%
plot(-5:0.1:5,γm,
xlabel="Threshold",
ylabel="Gamma",
line=:solid,
lab="calculated",
leg=false,
w=3)
plot!(-5:0.1:5,γm+2*sqrt(γv),c=:lightblue,line=:dash,w=3)
plot!(-5:0.1:5,γm-2*sqrt(γv),c=:lightblue,line=:dash,w=3)
plot!(x->EΓ(x,32),-5,5,w=2,lab="theoretical")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <defs>
#   <clipPath id="clip02">
#     <rect x="75" y="20" width="496" height="331"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,350 570,350
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,336.8 570,336.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,323.6 570,323.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,310.4 570,310.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,297.2 570,297.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,284 570,284
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,270.8 570,270.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,257.6 570,257.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,244.4 570,244.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,231.2 570,231.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,218 570,218
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,204.8 570,204.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,191.6 570,191.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,178.4 570,178.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,165.2 570,165.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,152 570,152
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,138.8 570,138.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,125.6 570,125.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,112.4 570,112.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,99.2 570,99.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,86 570,86
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,72.8 570,72.8
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,59.6 570,59.6
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,46.4 570,46.4
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,33.2 570,33.2
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   75,20 570,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   84.9,350 84.9,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   104.7,350 104.7,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   124.5,350 124.5,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   144.3,350 144.3,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   164.1,350 164.1,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   183.9,350 183.9,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   203.7,350 203.7,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   223.5,350 223.5,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   243.3,350 243.3,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   263.1,350 263.1,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   282.9,350 282.9,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   302.7,350 302.7,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   322.5,350 322.5,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   342.3,350 342.3,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   362.1,350 362.1,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   381.9,350 381.9,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   401.7,350 401.7,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   421.5,350 421.5,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   441.3,350 441.3,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   461.1,350 461.1,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   480.9,350 480.9,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   500.7,350 500.7,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   520.5,350 520.5,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   540.3,350 540.3,20
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   560.1,350 560.1,20
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; font-family:Arial; font-size:15; text-anchor:start;" transform="rotate(0, 45.6251, 354.23)" x="45.6251" y="354.23">-</text>
# </g>
# <g clip-path="url(#clip0
